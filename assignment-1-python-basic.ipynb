# %% [markdown]
# #                                            Assignment # 1

# %% [markdown]
# #                                                Task # 1

# %% [markdown]
# #1 - Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# ![jupyter-screenshot.png](attachment:jupyter-screenshot.png)

# %% [markdown]
# #2 - Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
seq = []
for i in range(2000,3201):
    if (i%7 == 0):
        if (i%5 != 0):
            seq.append(i)
print(seq)

# %% [markdown]
# #3 - Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
first_name = input()
last_name = input()
full_name =  first_name + " " + last_name
print(full_name [::-1])

# %% [markdown]
# #4 - Write a Python program to find the volume of a sphere with diameter 12 cm.
#      Formula: V=4/3 * π * r 3

# %%
import math
volume = 4/3 * (math.pi) * 12**3
print(volume, "cm\u00b3")

# %% [markdown]
# #                                               Task # 2

# %% [markdown]
# #1 - Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
input_number = input()
list1 = input_number.split(",")
print(list1)

# %% [markdown]
# #2 - Create the below pattern using nested for loop in Python.
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(0, 5):
    for j in range(0, i+1):
        print("* ", end="")
    print("\r")
for k in reversed(range(6)):
    for j in range(0, k-1):
        print("* ", end="")
    print("\r")

# %% [markdown]
# #3 - Write a Python program to reverse a word after accepting the input from the user.
# Sample Output:
# Input word: AcadGild
# Output: dilGdacA

# %%
input_word = input()
reverse_word_1 = input_word[::-1]
reverse_word = reverse_word_1
print(reverse_word.replace('i','l').replace('l','i',1))

# %% [markdown]
# #4 - Write a Python Program to print the given string in the format specified in the sample output.
#         WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
#         SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all
#         its citizens
#         Sample Output:
#         WE, THE PEOPLE OF INDIA,
#         having solemnly resolved to constitute India into a SOVEREIGN, !
#         SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#         and to secure to all its citizens

# %%
str_given = "WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens"
str = str_given.split(",")
last_string = str[5].split("and")
print(str[0] +","+ str[1] +"," "\n" + str[2].strip() +", !" +"\n" + str[3].strip() +"," + str[4] +"," +last_string[0] +"\n" +"and" +last_string[1])
